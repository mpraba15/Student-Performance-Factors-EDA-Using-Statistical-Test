# %% [markdown]
# # Student Performance Factors

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data Collection

# %%
df=pd.read_csv(r"C:\Users\NAN RAJA\Downloads\archive (21).zip")

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# #  Data Understanding

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.nunique()
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement           3
# Access_to_Resources            3
# Extracurricular_Activities     2
# Sleep_Hours                    7
# Previous_Scores               51
# Motivation_Level               3
# Internet_Access                2
# Tutoring_Sessions              9
# Family_Income                  3
# Teacher_Quality                3
# School_Type                    2
# Peer_Influence                 3
# Physical_Activity              7
# Learning_Disabilities          2
# Parental_Education_Level       3
# Distance_from_Home             3
# Gender                         2
# Exam_Score                    45
# dtype: int64

# %%
df.describe(include="all")
# Out:
#         Hours_Studied   Attendance Parental_Involvement Access_to_Resources  \
# count     6607.000000  6607.000000                 6607                6607
# unique            NaN          NaN                    3                   3
# top               NaN          NaN               Medium              Medium
# freq              NaN          NaN                 3362                3319
# mean        19.975329    79.977448                  NaN                 NaN
# std          5.990594    11.547475                  NaN                 NaN
# min          1.000000    60.000000                  NaN                 NaN
# 25%         16.000000    70.000000                  NaN                 NaN
# 50%         20.000000    80.000000                  NaN                 NaN
# 75%         24.000000    90.000000                  NaN                 NaN
# max         44.000000   100.000000                  NaN                 NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# # Data Pre-processing

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6602    False
# 6603    False
# 6604    False
# 6605    False
# 6606    False
# Length: 6378, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Univariate Analysis

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df["Hours_Studied"].value_counts()
# Out:
# Hours_Studied
# 20    448
# 19    425
# 21    420
# 18    393
# 23    389
# 22    386
# 17    370
# 24    343
# 16    337
# 15    303
# 25    281
# 14    257
# 26    255
# 27    217
# 13    213
# 12    189
# 28    169
# 11    140
# 29    131
# 30    119
# 10     91
# 9      79
# 31     75
# 8      55
# 32     54
# 7      51
# 33     37
# 34     27
# 5      21
# 35     20
# 6      17
# 4      16
# 3      12
# 36     10
# 38      7
# 37      6
# 39      6
# 2       4
# 1       3
# 43      1
# 44      1
# Name: count, dtype: int64

# %%
ax=df['Hours_Studied'].value_counts()[0:10].plot(kind='pie',title='Students Study Hours', autopct='%1.1f%%')
ax.legend(loc='center left',bbox_to_anchor=(1.3,0.5))
plt.show()

# %%
sns.histplot(x="Attendance",data=df,color="teal")
plt.xlabel('Attendance')
plt.ylabel('Number of Students')
plt.title("Attendance Distribution among Students")
plt.show()

# %%
df["Exam_Score"].value_counts()
# Out:
# Exam_Score
# 68     738
# 66     722
# 67     692
# 65     650
# 69     599
# 70     526
# 64     478
# 71     398
# 63     350
# 72     298
# 62     261
# 61     166
# 73     133
# 74     102
# 60      75
# 75      48
# 59      39
# 58      21
# 76      16
# 80       5
# 77       5
# 57       4
# 82       4
# 94       4
# 86       4
# 78       4
# 84       3
# 97       3
# 89       3
# 79       3
# 88       3
# 98       3
# 93       2
# 92       2
# 95       2
# 99       2
# 87       2
# 96       1
# 85       1
# 91       1
# 100      1
# 83       1
# 101      1
# 55       1
# 56       1
# Name: count, dtype: int64

# %%
sns.displot(x="Exam_Score", data=df,color="blue")
plt.xlabel('Exam_Score')
plt.ylabel('Number of Students')
plt.title("Student Exam_Score")
plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      3688
# Female    2690
# Name: count, dtype: int64

# %%
sns.countplot(x="Gender", data=df, color="orange",edgecolor="red")
plt.xlabel('Gender')
plt.ylabel('Number of Students')
plt.title("Count of Male Or Female")
plt.show()

# %%
sns.histplot(x="Hours_Studied",data=df,kde=True,color="green",edgecolor="black")
plt.xlabel('Hours_Studied')
plt.ylabel('Number of Students')
plt.title("How much time student spend on studies?")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Sleep_Hours", data=df, color="red")
plt.xlabel('Sleep_Hours')
plt.ylabel('Number of Students')
plt.title("Student of Sleep Hours")
plt.show()

# %%
df["Motivation_Level"].value_counts()
# Out:
# Motivation_Level
# Medium    3237
# Low       1864
# High      1277
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(x="Motivation_Level", data=df, color="powderblue")
plt.xlabel('Motivation_Level')
plt.ylabel('Number of Students')
plt.title("Motivation Level among Students")
plt.show()

# %%
plt.title("Attendance KDE Plot")
sns.kdeplot(x="Attendance",data=df,shade=True,edgecolor="blue")
plt.show()
# Out:
# C:\Users\NAN RAJA\AppData\Local\Temp\ipykernel_6020\3629633788.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x="Attendance",data=df,shade=True,edgecolor="blue")

# %%
sns.countplot(x="Parental_Education_Level", data=df, color="green")
plt.xlabel('Parental_Education_Level')
plt.ylabel('Number of parents')
plt.title("parents Education level ") 
plt.show()

# %%
ax=df['Family_Income'].value_counts()[0:10].plot(kind='pie',title='Students Family Income', autopct='%1.1f%%')
ax.legend(loc='center left',bbox_to_anchor=(1.3,0.5))
plt.show()

# %%
sns.countplot(x="Extracurricular_Activities", data=df, color="mistyrose")
plt.xlabel('Extracurricular_Activities')
plt.ylabel('Number of Students')
plt.title("Extracurricular_Activities") 
plt.show()

# %% [markdown]
# # Bi-variate Analysis

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='Hours_Studied', y='Exam_Score', data=df, hue='Gender', palette='bright')
plt.title('Hours Studied vs Exam Score')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='Sleep_Hours', y='Exam_Score', data=df, hue='Gender')
plt.title('Sleep Hours for  vs Exam Score')
plt.xlabel('Sleep Hours')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
sns.barplot(x="Hours_Studied",y="Exam_Score",data=df.head(20),edgecolor="red",palette="viridis")
plt.title("Student Study of Exam Score")
plt.show()
# Out:
# C:\Users\NAN RAJA\AppData\Local\Temp\ipykernel_6020\3154681171.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Hours_Studied",y="Exam_Score",data=df.head(20),color="pink",edgecolor="red",palette="viridis")

# %%
sns.barplot(x="Attendance",y="Exam_Score",data=df.head(10),palette="viridis")
plt.title("Student Study of Exam Score")
plt.show()
# Out:
# C:\Users\NAN RAJA\AppData\Local\Temp\ipykernel_6020\2092808461.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Attendance",y="Exam_Score",data=df.head(10),palette="viridis")

# %%
df["Extracurricular_Activities"].value_counts()
# Out:
# Extracurricular_Activities
# Yes    3807
# No     2571
# Name: count, dtype: int64

# %%
sns.violinplot(x="Extracurricular_Activities",y="Exam_Score",data=df.head(30),color="pink")
plt.title("Student in Activities find Exam_Score")
plt.show()

# %%
sns.violinplot(x="Gender",y="Exam_Score",data=df.head(30),color="teal")
plt.title("Gender of High Score")
plt.show()

# %% [markdown]
# # Multi_variate Analysis

# %%
sns.barplot(df)
plt.xticks(rotation=70)
plt.title("All over Student Performance")
plt.show()

# %%
sns.pairplot(df)

# %%
## Statistical Tes

# %% [markdown]
# # Two sample ind-T-Test

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
group_a = df[df['Gender'] == 'Male']['Exam_Score']
group_b = df[df['Gender'] == 'Female']['Exam_Score']

# %%
group_a
# Out:
# 0       67
# 2       74
# 3       71
# 5       71
# 6       67
#         ..
# 6587    67
# 6588    65
# 6591    66
# 6592    72
# 6606    64
# Name: Exam_Score, Length: 3688, dtype: int64

# %%
group_b
# Out:
# 1       61
# 4       70
# 15      64
# 17      65
# 18      67
#         ..
# 6601    65
# 6602    68
# 6603    69
# 6604    68
# 6605    68
# Name: Exam_Score, Length: 2690, dtype: int64

# %%
#Perform a t-test to compare means
F, p_value = stats.ttest_ind(group_a, group_b)

# %%
F, p_value
# Out:
# (-0.39386280795717277, 0.6936955012015205)

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between groups A and B")
else:
    print("Fail to reject the null hypothesis: No significant difference between groups A and B")
# Out:
# Fail to reject the null hypothesis: No significant difference between groups A and B

# %%
group_a.var()
# Out:
# 14.318480699908633

# %%
group_b.var()
# Out:
# 16.700625154663854
